# %% [markdown]
# # План домашних заданий

# %% [markdown]
# - Описание задачи и знакомство с данными
# - Домашнее задание 1. Генерация и фильтрация признаков
# - Домашнее задание 2. Прогноз времени и вида поломки машин, настройка ML-модели
# - Дополнительное задание. Визуализация прогнозов, ошибок модели и важности признаков
# - Домашнее задание 3. Оптимизация. Тюнинг гиперпараметров с помощью `Optuna`
# - Домашнее задание 4. Блендинг
# - Домашнее задание 5. Парсинг внешних данных и оптимизация памяти
# - Отправка финального решения на лидерборд на Kaggle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # <center id="part0"> Описание задачи

# %% [markdown]
# **Предыстория:**  мы работаем с каршеринговой компанией, которая управляет крупным автопарком машин. Наша цель — предотвратить длительные периоды простоя машин из-за поломок через своевременное обслуживание и ремонт.
#
#
# **Идея для решения проблемы:** создать приоритизированный список обхода машин. Этот список поможет технической бригаде сосредоточиться на автомобилях, которые наиболее вероятно выйдут из строя в ближайшее время.
#
#
# **Как компания решает задачу:**
#
# * Собирает данные о поездках и состоянии машин до поломок.
#
# * Нанимает Data Scientist, чтобы он смог использовать эти данные для анализа и прогнозирования характера поломок.
#
# **Важный момент**: задачи этого специалиста (Data Scientist) предстоит выполнять вам.

# %% [markdown]
# ## <center> Знакомство с данными

# %% [markdown]
# ### Информация про машины с таргетом (основной датасет)

# %%
car_train = pd.read_csv('https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/car_train.csv')
car_train.sample(5)
# Out:
#           car_id           model  car_type fuel_type  car_rating  \
# 555   G62087174h  Renault Kaptur  standart    petrol        4.60
# 878   y16050355z  Renault Kaptur  standart    petrol        4.28
# 211   Y-1582411z   Smart ForFour   economy    petrol        2.98
# 1359  f-1833647Q   Smart ForFour   economy    petrol        4.98
# 1182  q14308699p  Renault Kaptur  standart    petrol        2.74
#
#       year_to_start  riders  year_to_work  target_reg     target_class
# 555            2011    2306          2020       38.81      electro_bug
# 878            2012   21143          2019       26.63        break_bug
# 211            2016  115362          2015       57.81  engine_ignition
# 1359           2014   60544          2020       57.34  engine_ignition
# 1182           2013   39299          2020       30.74        break_bug

# %% [markdown]
# - `car_id` — идентификатор машины
# - `model` / `car_type` / `fuel_type` — марка, класс и тип топлива машины
# - `car_rating` / `riders` — общий рейтинг и общее число поездок к концу 2021 года
# - `year_to_start` / `year_to_work` — год выпуска машины и год начала работы в автопарке
# - `target_reg` — количество дней до поломки
# - `target_class` — класс поломки (всего 9 видов)

# %% [markdown]
# ### Информация про поездки

# %%
rides_info = pd.read_csv('https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/rides_info.csv')
rides_info.sample(5)
# Out:
#            user_id      car_id ride_id   ride_date  rating  ride_duration  \
# 212320  R15885293d  P-1424840K     h1h  2020-01-22    5.01             51
# 381748  X20190007y  b-1600009O     r1A  2020-03-29    5.19            122
# 284     Z18411963n  A-1079539w     i1F  2020-02-28    5.96             32
# 137806  h13924197U  J32481265i     q1r  2020-04-01    3.11          26998
# 263070  y16293574p  S-4942615g     S1T  2020-03-23    6.02             40
#
#         ride_cost  speed_avg   speed_max  stop_times      distance  refueling  \
# 212320        710         39   95.000000           9  1.889383e+03          0
# 381748       1948         72   97.042974           5  9.325603e+02          0
# 284           411         41   82.000000           3  7.307444e+02          0
# 137806     269975         39   49.000000           3  1.076928e+06          0
# 263070        355         58  143.207602           0  2.347192e+03          0
#
#         user_ride_quality  deviation_normal
# ...

# %% [markdown]
# - `user_id` / `car_id` / `ride_id` — идентификаторы водителя, машины, поездки соответственно
# - `ride_date` / `rating` — дата поездки и рейтинг, поставленный водителем
# - `ride_duration` / `distance` / `ride_cost` —  длительность (время),  пройденное расстояние, стоимость поездки
# - `speed_avg` / `speed_max` — средняя и максимальная скорости поездки соответственно
# - `stop_times` / `refueling` — количество остановок (паузы) и флаг: была ли дозаправка
# - `user_ride_quality` — оценка манеры вождения водителя машины, определенная скоринговой ML-системой сервиса
# - `deviation_normal` — общий показатель датчиков о состоянии машины, относительно эталонных показателей (нормы)

# %% [markdown]
# ### Информация про водителей

# %%
driver_info = pd.read_csv('https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/driver_info.csv')
driver_info.sample(5)
# Out:
#        age  user_rating  user_rides  user_time_accident     user_id  sex  \
# 6413    27          9.1        1331                17.0  O12365678X    1
# 12380   33          7.6         876                 9.0  f88378672r    0
# 6930    40          8.1        1067                 NaN  l20002157B    0
# 14834   44          8.4         451                17.0  A94879389l    0
# 6102    27          8.5        1100                24.0  a34744073e    1
#
#       first_ride_date
# 6413         2018-9-4
# 12380       2019-3-26
# 6930        2021-2-16
# 14834       2020-6-10
# 6102        2018-11-4

# %% [markdown]
# - `user_id` / `age` / `sex` — идентификатор, возраст и пол водителя, соответственно
# - `user_rating` — общий рейтинг пользователя за все поездки к концу 2021 года
# - `user_rides` — общее количество поездок к концу 2021 года
# - `user_time_accident` — число инцидентов (это могли быть аварии/штрафы/эвакуация машины)
# - `first_ride_date` — дата первой поездки

# %% [markdown]
# ### Информация про ремонт машин

# %%
fix_info = pd.read_csv('https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/fix_info.csv')
fix_info.sample(5)
# Out:
#             car_id worker_id          fix_date  work_type  destroy_degree  \
# 14311   j18870600U        TY     2020-5-23 5:3     repair             5.0
# 106713  l60900580P        SP    2020-1-10 9:20     repair             6.7
# 63318   S-6684161s        MG  2019-10-13 18:41  reparking             1.0
# 35176   o87681914x        KB   2019-11-22 0:52  reparking             1.0
# 53490   e-2141689x        WY   2018-4-13 10:56  reparking            10.0
#
#         work_duration
# 14311              26
# 106713             30
# 63318              27
# 35176              20
# 53490              59

# %% [markdown]
# - `worker_id` / `car_id` — идентификатор работника и машины
# - `work_type` / `work_duration` — тип и длительность (в часах) проводимой работы
# - `destroy_degree` — степень износа/поврежденности машины в случае поломки
# - `fix_date` — время начала ремонта (снятия машины с линии)

# %% [markdown]
# # Домашнее задание 1. Генерация и фильтрация признаков

# %% [markdown]
# <center> <img src="https://ucarecdn.com/bf4c772d-b67a-42ae-a48b-cfd83910b0a2/" width=700>

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — сгенерировать признаки из дополнительных датасетов и добавить их к основному датасету, произвести фильтрацию признаков.

# %% [markdown]
#
# ## Задание 1. Генерация признаков из дополнительных датасетов (6 баллов)

# %% [markdown]
# <div class="alert alert-info">
#
# 1. Возьмите датасет `rides_info` с информацией о поездках и проведите группировку по каждой машине отдельно.
#
# 2. Для каждой машины (то есть для каждого `car_id`) подсчитайте несколько признаков:
#   - минимальный рейтинг за все поездки;
#   - средний рейтинг за все поездки;
#   - общее количество километров, которое машина проехала;
#   - максимальная скорость;
#   - общее количество поездок для каждой машины.
#
# 3. Добавьте минимум 3 признака на свой выбор.
#
# 4. Сделайте соединение таблиц — вспомните про методы соединения и выберите подходящий для этого случая.
#
# 5. Подключите информацию про водителей (`driver_info`) и про ремонт машин (`fix_info`). Добавьте минимум 3 любых признака с каждого датасета.
#
#
# <h4> Критерии оценивания </h4>
#
# - Добавлены 5 обязательных и минимум 3 любых признака из датасета `rides_info` — 2 балла.
# - Добавлены минимум 3 любых признака из датасета `driver_info` — 2 балла.
# - Добавлены минимум 3 любых признака из датасета `fix_info` — 2 балла.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
#
# <h4> Советы по Feature Engineering</h4>
#
# - Начинайте с сырых данных.
# - Используйте все доступные данные. Покрывайте признаками всю имеющуюся информацию в данных.
# - Формулируйте предположения: от чего зависит таргет?
# - Смотрите визуально на классы/ошибки и делайте предположения. Какие полезны?
# - Помните, что слишком много признаков может быть вредно. Потом придется отфильтровывать.
#
# <h4> Полезные источники </h4>
#
# - Занятие про Feature Engineering.
# - Занятие про Feature Selection.
# - [Max Kuhn and Kjell Johnson. Feature Engineering and Selection: A Practical Approach for Predictive Models](http://www.feat.engineering/).

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # **РЕШЕНИЕ**

# %%
unique_values_count = car_train['car_id'].nunique() #определение количества уникальных id машин
print(unique_values_count)# вывод количество данных уникальных
print(car_train.info())#информация общая о датасете для определения количества различных машин в датасете
# Out:
# 2337
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   car_id         2337 non-null   object
#  1   model          2337 non-null   object
#  2   car_type       2337 non-null   object
#  3   fuel_type      2337 non-null   object
#  4   car_rating     2337 non-null   float64
#  5   year_to_start  2337 non-null   int64
#  6   riders         2337 non-null   int64
#  7   year_to_work   2337 non-null   int64
#  8   target_reg     2337 non-null   float64
#  9   target_class   2337 non-null   object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 182.7+ KB
# None

# %%
unique_values_count_2 = rides_info['user_id'].nunique() #определение количества уникальных id водителей
print(unique_values_count_2)# вывод количество данных уникальных
# Out:
# 15153

# %%
# Для каждой машины подсчитываем необходимые признаки из базы rides_info - данные о поездках

result_car_id = rides_info.groupby('car_id').agg({
    'rating': ['min', 'mean'], #минимальный рейтинг за все поездки, средний рейтинг за все поездки - по заданию
    'distance': 'sum', #общее количество километров, которое машина проехала - по заданию
    'speed_max': 'max', #максимальная скорость - по заданию
    'ride_id': 'count', #общее количество поездок для каждой машины - по заданию

    'stop_times':'sum', #общее количество остановок  - количество остановок увеличивает износ машины
    'ride_duration':'sum',# общая длительность поездок
    'deviation_normal':['min'], #максимальное отклонение от нормы вниз  - покажет интенсивность износа
    'user_ride_quality': 'mean' #средняя оценка вождения машины (как стиль вождения)
})

#print(result_car_id)

# Переименовываем столбцы для удобства
result_car_id.columns = ['min_rating', 'mean_rating', 'sum_distance', 'max_speed',
                         'count_rides', 'total_stops', 'sum_ride_duration', 'min_deviation_normal', 'mean_user_ride_quality']

# Создаем новый DataFrame с агрегированными данными
new_df = pd.DataFrame(result_car_id)

# Выводим новый DataFrame
#print(new_df)

# %%
new_df.reset_index(inplace=True)

# Присоединяем new_df к rides_info через столбец 'car_id' с помощью метода merge
merged_df = car_train.merge(new_df, on='car_id', how='left')

merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   car_id                  2337 non-null   object
#  1   model                   2337 non-null   object
#  2   car_type                2337 non-null   object
#  3   fuel_type               2337 non-null   object
#  4   car_rating              2337 non-null   float64
#  5   year_to_start           2337 non-null   int64
#  6   riders                  2337 non-null   int64
#  7   year_to_work            2337 non-null   int64
#  8   target_reg              2337 non-null   float64
#  9   target_class            2337 non-null   object
#  10  min_rating              2337 non-null   float64
#  11  mean_rating             2337 non-null   float64
#  12  sum_distance            2337 non-null   float64
#  13  max_speed               2337 non-null   float64
# ...

# %%
merged_df.sample(5)#вывод 5-ти случайных строк
# Out:
#           car_id           model  car_type fuel_type  car_rating  \
# 971   z-1104831H    Kia Sportage  standart    petrol        5.06
# 1447  p22133368b   Tesla Model 3   premium   electro        3.06
# 1748  b-1350184G  Nissan Qashqai  standart    petrol        5.96
# 1687  D-1643531L  Renault Kaptur  standart    petrol        4.72
# 957   O-9487423J  Kia Rio X-line   economy    petrol        7.10
#
#       year_to_start  riders  year_to_work  target_reg     target_class  \
# 971            2012   19285          2020       26.58      engine_fuel
# 1447           2014   66621          2019       63.47      electro_bug
# 1748           2015   79090          2019       59.25  engine_ignition
# 1687           2012   22296          2021       56.00     engine_check
# 957            2015   93798          2018       23.88      electro_bug
#
#       min_rating  mean_rating  sum_distance   max_speed  count_rides  \
# 971          0.1     4.199713  1.450104e+07  167.522561          174
# ...

# %% [markdown]
# _______
# _______

# %% [markdown]
# Так как данные в таблице driver_info содержат данные по id водителей и не содержит данных по id машин, а основная база не содержит данных по водителям, то необходимо сначала привести в соотвествие данные по водителям, а затем их сгруппировать по id  машин и соединить с основной базой.

# %%
merged_df_2 = rides_info.merge(driver_info, on='user_id', how='left')
merged_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 739500 entries, 0 to 739499
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   user_id             739500 non-null  object
#  1   car_id              739500 non-null  object
#  2   ride_id             739500 non-null  object
#  3   ride_date           739500 non-null  object
#  4   rating              739500 non-null  float64
#  5   ride_duration       739500 non-null  int64
#  6   ride_cost           739500 non-null  int64
#  7   speed_avg           739500 non-null  int64
#  8   speed_max           736139 non-null  float64
#  9   stop_times          739500 non-null  int64
#  10  distance            739500 non-null  float64
#  11  refueling           739500 non-null  int64
#  12  user_ride_quality   736872 non-null  float64
#  13  deviation_normal    739500 non-null  float64
#  14  age                 739500 non-null  int64
# ...

# %%
# user_id / age / sex — идентификатор, возраст и пол водителя, соответственно
   # user_rating — общий рейтинг пользователя за все поездки к концу 2021 года
   # user_rides — общее количество поездок к концу 2021 года
   # user_time_accident — число инцидентов (это могли быть аварии/штрафы/эвакуация машины)
   # first_ride_date — дата первой поездки

#не важные данные  -
#пол (больше влияет не пол, а рейтинг),
#дата первой поездки(не определяет стиля вождения),
#общее количество поездок (может быть на разных машинах),
#число инцидентов - определяет водителя, а не количество поломок, т.к. возможны поездки на других машинах


result_2 = merged_df_2.groupby('car_id').agg({
    'user_id': 'nunique', #количество водителей - может быть признаком знакомства с особенностью машины
    'user_rating':'mean',# средний рейтинг водителей - может быть полезен с точки зрения вероятности поломки
    'age':['min', 'mean', 'max'] #минимальный, средний и максимальный возраст водителей - может быть важен
})

# Переименовываем столбцы для удобства
result_2.columns = ['sum_user_id', 'mean_user_rating', 'min_age','mean_age', 'max_age']

# Создаем новый DataFrame с агрегированными данными
new_df_2 = pd.DataFrame(result_2)

# Выводим новый DataFrame
print(new_df_2)
# Out:
#             sum_user_id  mean_user_rating  min_age   mean_age  max_age
# car_id
# A-1049127W          172          7.817816       18  33.666667       60
# A-1079539w          173          7.773563       18  32.344828       61
# A-1162143G          172          8.149425       18  34.241379       58
# A-1228282M          174          8.045402       18  33.609195       60
# A-1339912r          172          8.195402       18  33.948276       58
# ...                 ...               ...      ...        ...      ...
# z73688663a          168          8.156322       18  32.327586       58
# z73740510r          171          8.096552       21  36.097701       57
# z86911952C          172          8.014368       18  33.195402       55
# z91353693Z          173          8.024138       18  34.839080       61
# z91796444U          174          7.763218       18  33.143678       56
#
# [4250 rows x 5 columns]

# %%
new_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4250 entries, A-1049127W to z91796444U
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sum_user_id       4250 non-null   int64
#  1   mean_user_rating  4250 non-null   float64
#  2   min_age           4250 non-null   int64
#  3   mean_age          4250 non-null   float64
#  4   max_age           4250 non-null   int64
# dtypes: float64(2), int64(3)
# memory usage: 199.2+ KB

# %%
merged_df_3 = merged_df.merge(new_df_2, on='car_id', how='left')
merged_df_3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   car_id                  2337 non-null   object
#  1   model                   2337 non-null   object
#  2   car_type                2337 non-null   object
#  3   fuel_type               2337 non-null   object
#  4   car_rating              2337 non-null   float64
#  5   year_to_start           2337 non-null   int64
#  6   riders                  2337 non-null   int64
#  7   year_to_work            2337 non-null   int64
#  8   target_reg              2337 non-null   float64
#  9   target_class            2337 non-null   object
#  10  min_rating              2337 non-null   float64
#  11  mean_rating             2337 non-null   float64
#  12  sum_distance            2337 non-null   float64
#  13  max_speed               2337 non-null   float64
# ...

# %%
merged_df_3.head()
# Out:
#        car_id              model  car_type fuel_type  car_rating  \
# 0  y13744087j     Kia Rio X-line   economy    petrol        3.78
# 1  O41613818T         VW Polo VI   economy    petrol        3.90
# 2  d-2109686j    Renault Sandero  standart    petrol        6.30
# 3  u29695600e  Mercedes-Benz GLC  business    petrol        4.04
# 4  N-8915870N    Renault Sandero  standart    petrol        4.70
#
#    year_to_start  riders  year_to_work  target_reg target_class  ...  \
# 0           2015   76163          2021      108.53  another_bug  ...
# 1           2015   78218          2021       35.20  electro_bug  ...
# 2           2012   23340          2017       38.62   gear_stick  ...
# 3           2011    1263          2020       30.34  engine_fuel  ...
# 4           2012   26428          2017       30.45  engine_fuel  ...
#
#    count_rides  total_stops  sum_ride_duration  min_deviation_normal  \
# 0          174          630             284624                -9.000
# ...

# %% [markdown]
# ___

# %%
fix_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146000 entries, 0 to 145999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   car_id          146000 non-null  object
#  1   worker_id       146000 non-null  object
#  2   fix_date        146000 non-null  object
#  3   work_type       146000 non-null  object
#  4   destroy_degree  146000 non-null  float64
#  5   work_duration   146000 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
fix_info.head()
# Out:
#        car_id worker_id         fix_date     work_type  destroy_degree  \
# 0  P17494612l        RJ   2020-6-20 2:14     reparking             8.0
# 1  N-1530212S        LM   2020-2-9 20:25        repair            10.0
# 2  B-1154399t        ND    2019-8-24 7:1     reparking             1.0
# 3  y13744087j        PG   2019-8-10 9:29     reparking             1.0
# 4  F12725233R        YC  2020-11-12 5:22  refuel_check             8.0
#
#    work_duration
# 0             49
# 1             48
# 2             27
# 3             28
# 4             47

# %%
   # worker_id / car_id — идентификатор работника и машины
   #work_type / work_duration — тип и длительность (в часах) проводимой работы
   # destroy_degree — степень износа/поврежденности машины в случае поломки
   #fix_date — время начала ремонта (снятия машины с линии)
#не значащие данные
#worker_id - вряд ли имееет значение
#fix_date - вероятнее всего не может быть в прямую оценена


result_3 = fix_info.groupby('car_id').agg({
    'work_duration': ['min', 'mean', 'max'], #длительность простоя в часах: миниммальная, максимальная, средняя
})

# Переименовываем столбцы для удобства
result_3.columns = ['min_work_duration', 'mean_work_duration', 'max_work_duration']

# Создаем новый DataFrame с агрегированными данными
new_df_3 = pd.DataFrame(result_3)

# Выводим новый DataFrame
print(new_df_3)
# Out:
#             min_work_duration  mean_work_duration  max_work_duration
# car_id
# A-1049127W                  1           27.485714                 56
# A-1079539w                  3           27.382353                 64
# A-1162143G                  1           27.823529                 69
# A-1228282M                  3           24.647059                 65
# A-1339912r                  3           28.617647                 71
# ...                       ...                 ...                ...
# z73688663a                 11           26.028571                 59
# z73740510r                  3           25.457143                 49
# z86911952C                  1           26.942857                 48
# z91353693Z                  1           28.764706                 68
# z91796444U                  1           25.942857                 63
#
# [4250 rows x 3 columns]

# %%
merged_df_4 = merged_df_3.merge(new_df_3, on='car_id', how='left')
merged_df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   car_id                  2337 non-null   object
#  1   model                   2337 non-null   object
#  2   car_type                2337 non-null   object
#  3   fuel_type               2337 non-null   object
#  4   car_rating              2337 non-null   float64
#  5   year_to_start           2337 non-null   int64
#  6   riders                  2337 non-null   int64
#  7   year_to_work            2337 non-null   int64
#  8   target_reg              2337 non-null   float64
#  9   target_class            2337 non-null   object
#  10  min_rating              2337 non-null   float64
#  11  mean_rating             2337 non-null   float64
#  12  sum_distance            2337 non-null   float64
#  13  max_speed               2337 non-null   float64
# ...

# %%
merged_df_4.head(5)
# Out:
#        car_id              model  car_type fuel_type  car_rating  \
# 0  y13744087j     Kia Rio X-line   economy    petrol        3.78
# 1  O41613818T         VW Polo VI   economy    petrol        3.90
# 2  d-2109686j    Renault Sandero  standart    petrol        6.30
# 3  u29695600e  Mercedes-Benz GLC  business    petrol        4.04
# 4  N-8915870N    Renault Sandero  standart    petrol        4.70
#
#    year_to_start  riders  year_to_work  target_reg target_class  ...  \
# 0           2015   76163          2021      108.53  another_bug  ...
# 1           2015   78218          2021       35.20  electro_bug  ...
# 2           2012   23340          2017       38.62   gear_stick  ...
# 3           2011    1263          2020       30.34  engine_fuel  ...
# 4           2012   26428          2017       30.45  engine_fuel  ...
#
#    min_deviation_normal  mean_user_ride_quality  sum_user_id  \
# 0                -9.000               -0.901190          170
# ...

# %% [markdown]
# ### Идеи для новых признаков
#
# 1.   Новый пункт
# 2.   Новый пункт

# %% [markdown]
# * `feature_min_max_diff` — разница между максимальным и минимальным значениями `deviation_normal` для каждой машины
# * `feature_corner` — угол наклона по признаку `user_ride_quality` для каждой машины
# * `feature_mean` — среднее значение `deviation_normal` для каждой машины
# * `feature_shift` — точка перегиба/сдвига для `deviation_normal`
# * `feature_start` — значение точки старта для `deviation_normal`
# * `feature_nans` — сумма пропусков для столбца `...` для каждой машины
# * `feature_quant` — `X %` квантиль для столбца `...` для каждой машины
#
# Подумайте, какие из признаков могут оказаться самыми полезными?

# %%
# YOUR CODE HERE

# %% [markdown]
# ## Задание 2. Применение методов фильтрации признаков (4 балла)
#
# <center> <img src="https://ucarecdn.com/d1b4bc78-fd04-44fb-bdbf-0a63355b7384/" width=700>

# %% [markdown]
# 1. Выберите и примените любые 3 (можно и больше) метода фильтрации, которые указаны выше или в ноутбуке по фильтрации из полезных ссылок.
# 2. Проинтерпретируйте результаты и сделайте выводы.
#
#
# <h4> Критерии оценивания </h4>
#
# - Применены методы фильтрации — 1 балл за каждый метод, максимум 3 балла.
# - Сделаны выводы на основе примененных методов —1 балл.
# </div>

# %% [markdown]
# ### Советы по Feature Selection

# %% [markdown]
# <div class="alert alert-info">
#
# <h3><center>Зачем отбирать признаки</center></h3>
#
# **Основные причины**:
#
# - Главная причина: с увеличением количества признаков часто падает точность предсказания модели, а некоторые модели и вовсе перестают адекватно работать. Так происходит, если в данных большое количество мусорных фичей (почти не коррелирующих с таргетом).
#
# - Если фичей очень много, то данные перестают помещаться в память и существенно увеличивают время обучения модели, особенно если мы тестируем несколько алгоритмов или ансамбль. Также важно учитывать, что платформы имеют ограничения на длительность одной сессии (в Kaggle — 12 часов) и лимиты по потребляемой памяти.
#
# - Даже если точность не снижается, есть риск, что модель опирается на шумные фичи, что снизит стабильность прогноза на приватной выборке.

# %% [markdown]
# <b>Что удалить сразу:</b>
#
# - константы;
# - уникальные значения (в том числе в тесте; как правило, это ID-шники по типу `car_id`).
#
# <b>Какие методы использовать:</b>
#
# - `Линейная корреляция`.
# - `Phik` — тоже корреляция, но на стероидах ([туториал на Medium](https://towardsdatascience.com/phik-k-get-familiar-with-the-latest-correlation-coefficient-9ba0032b37e7)).
# - `Permutation importance` (из `scikit-learn`).
# - `SHAP values` (из библиотеки `shap`).
# - `CatBoost Feature Selection` (рекурсивные методы).

# %%
#отсеивание признаков
merged_df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   car_id                  2337 non-null   object
#  1   model                   2337 non-null   object
#  2   car_type                2337 non-null   object
#  3   fuel_type               2337 non-null   object
#  4   car_rating              2337 non-null   float64
#  5   year_to_start           2337 non-null   int64
#  6   riders                  2337 non-null   int64
#  7   year_to_work            2337 non-null   int64
#  8   target_reg              2337 non-null   float64
#  9   target_class            2337 non-null   object
#  10  min_rating              2337 non-null   float64
#  11  mean_rating             2337 non-null   float64
#  12  sum_distance            2337 non-null   float64
#  13  max_speed               2337 non-null   float64
# ...

# %%
#определим количество уникальных значений в каждом из столбцов

# Получение количества уникальных значений в каждом столбце
unique_value_counts = merged_df_4.nunique()

# Вывод количества уникальных значений для каждого столбца
print(unique_value_counts)
# Out:
# car_id                    2337
# model                       26
# car_type                     4
# fuel_type                    2
# car_rating                 269
# year_to_start                7
# riders                    2306
# year_to_work                 9
# target_reg                1891
# target_class                 9
# min_rating                  91
# mean_rating               2223
# sum_distance              2337
# max_speed                 1938
# count_rides                  1
# total_stops                269
# sum_ride_duration         2328
# min_deviation_normal      2090
# mean_user_ride_quality    2337
# sum_user_id                 30
# mean_user_rating           785
# min_age                      4
# mean_age                   726
# max_age                     13
# min_work_duration           18
# mean_work_duration         620
# max_work_duration           44
# dtype: int64

# %%
#в резудльтате полученных данных номер индивидуальный машины можно удалить
# Удаление столбца 'car_id'
merged_df_4 = merged_df_4.drop('car_id', axis=1)

# Вывод датафрейма после удаления столбца
print("\nПосле удаления столбца:")
merged_df_4.head(2)
# Out:
# После удаления столбца:
#             model car_type fuel_type  car_rating  year_to_start  riders  \
# 0  Kia Rio X-line  economy    petrol        3.78           2015   76163
# 1      VW Polo VI  economy    petrol        3.90           2015   78218
#
#    year_to_work  target_reg target_class  min_rating  ...  \
# 0          2021      108.53  another_bug         0.1  ...
# 1          2021       35.20  electro_bug         0.0  ...
#
#    min_deviation_normal  mean_user_ride_quality  sum_user_id  \
# 0                -9.000               -0.901190          170
# 1               -25.088               14.018105          174
#
#    mean_user_rating  min_age   mean_age  max_age  min_work_duration  \
# 0          8.229885       18  33.511494       62                  7
# 1          7.988506       18  34.988506       57                  4
#
#    mean_work_duration  max_work_duration
# 0           26.657143                 56
# 1           24.942857                 48
#
# ...

# %%
#в результате полученных данных count_rides можно удалить
# Удаление столбца 'count_ride'
merged_df_4 = merged_df_4.drop('count_rides', axis=1)

# Вывод датафрейма после удаления столбца
print("\nПосле удаления столбца:")
merged_df_4.head(2)
# Out:
# После удаления столбца:
#             model car_type fuel_type  car_rating  year_to_start  riders  \
# 0  Kia Rio X-line  economy    petrol        3.78           2015   76163
# 1      VW Polo VI  economy    petrol        3.90           2015   78218
#
#    year_to_work  target_reg target_class  min_rating  ...  \
# 0          2021      108.53  another_bug         0.1  ...
# 1          2021       35.20  electro_bug         0.0  ...
#
#    min_deviation_normal  mean_user_ride_quality  sum_user_id  \
# 0                -9.000               -0.901190          170
# 1               -25.088               14.018105          174
#
#    mean_user_rating  min_age   mean_age  max_age  min_work_duration  \
# 0          8.229885       18  33.511494       62                  7
# 1          7.988506       18  34.988506       57                  4
#
#    mean_work_duration  max_work_duration
# 0           26.657143                 56
# 1           24.942857                 48
#
# ...

# %%
#Визуализация данных при помощи гистограмм
merged_df_4.hist(figsize = (20, 12), layout = (-1, 5), bins=30);

# %%
#для последующих работ необходимо категориальные признаки перевести в числовые
merged_df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   model                   2337 non-null   object
#  1   car_type                2337 non-null   object
#  2   fuel_type               2337 non-null   object
#  3   car_rating              2337 non-null   float64
#  4   year_to_start           2337 non-null   int64
#  5   riders                  2337 non-null   int64
#  6   year_to_work            2337 non-null   int64
#  7   target_reg              2337 non-null   float64
#  8   target_class            2337 non-null   object
#  9   min_rating              2337 non-null   float64
#  10  mean_rating             2337 non-null   float64
#  11  sum_distance            2337 non-null   float64
#  12  max_speed               2337 non-null   float64
#  13  total_stops             2337 non-null   int64
# ...

# %%
merged_df_5=merged_df_4.copy()
merged_df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   model                   2337 non-null   object
#  1   car_type                2337 non-null   object
#  2   fuel_type               2337 non-null   object
#  3   car_rating              2337 non-null   float64
#  4   year_to_start           2337 non-null   int64
#  5   riders                  2337 non-null   int64
#  6   year_to_work            2337 non-null   int64
#  7   target_reg              2337 non-null   float64
#  8   target_class            2337 non-null   object
#  9   min_rating              2337 non-null   float64
#  10  mean_rating             2337 non-null   float64
#  11  sum_distance            2337 non-null   float64
#  12  max_speed               2337 non-null   float64
#  13  total_stops             2337 non-null   int64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

#категориальные значения в датасете
#model
#car_type
#fuel_type
#target_class
# Определяем список категориальных столбцов
categorical_cols = merged_df_4.select_dtypes(include=['object']).columns

# Применяем Label Encoding к категориальным столбцам
label_encoders = {}
for col in categorical_cols:
    label_encoders[col] = LabelEncoder()
    merged_df_4[col] = label_encoders[col].fit_transform(merged_df_4[col])

# Выводим результат
merged_df_4.head()
# Out:
#    model  car_type  fuel_type  car_rating  year_to_start  riders  \
# 0      8         1          1        3.78           2015   76163
# 1     23         1          1        3.90           2015   78218
# 2     16         3          1        6.30           2012   23340
# 3     12         0          1        4.04           2011    1263
# 4     16         3          1        4.70           2012   26428
#
#    year_to_work  target_reg  target_class  min_rating  ...  \
# 0          2021      108.53             0         0.1  ...
# 1          2021       35.20             2         0.0  ...
# 2          2017       38.62             7         0.1  ...
# 3          2020       30.34             4         0.1  ...
# 4          2017       30.45             4         0.1  ...
#
#    min_deviation_normal  mean_user_ride_quality  sum_user_id  \
# 0                -9.000               -0.901190          170
# 1               -25.088               14.018105          174
# ...

# %%
# визуализация при помощи линейной корреляции
corrs = merged_df_4.dropna().corr().round(3).sort_values('target_reg')
sns.heatmap(corrs,
            cmap = 'Greens',
            square=True,
            vmin = 0)
# Out:
# <Axes: >

# %% [markdown]
# По результатам данной тепловой карты можно сделать вывод, что наибольшее линейное влияние оказывает на количество дней до поломки -
# максимальная скорость и количество остановов, и средний рейтинг водителя. Далее по степени выраженности корреляции влияет минимальный возраст водителя, показатели датчиков.

# %% [markdown]
# ______
# ## Phik

# %%
#Phik
# !pip install phik -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 6.6 MB/s eta 0:00:00

# %%
import phik
from phik.report import plot_correlation_matrix
from phik import report

# %%
phik_overview = merged_df_4.phik_matrix().round(2).sort_values('target_reg')

plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map="Greens",
                        title=r"correlation $\phi_K$",
                        fontsize_factor=0.8, figsize=(11, 6))
plt.tight_layout()
# Out:
# interval columns not set, guessing: ['model', 'car_type', 'fuel_type', 'car_rating', 'year_to_start', 'riders', 'year_to_work', 'target_reg', 'target_class', 'min_rating', 'mean_rating', 'sum_distance', 'max_speed', 'total_stops', 'sum_ride_duration', 'min_deviation_normal', 'mean_user_ride_quality', 'sum_user_id', 'mean_user_rating', 'min_age', 'mean_age', 'max_age', 'min_work_duration', 'mean_work_duration', 'max_work_duration']

# %% [markdown]
# **Выводы:** Данные Phik повторили данные, которые продемонстрировала линейная корреляция. Добавились значения лишь: тип поломки и количество водителей, заказывающих эти авто.

# %% [markdown]
# ____
# ## Feature Importance

# %%
# !pip install catboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 9.4 MB/s eta 0:00:00
# ...

# %%
from catboost import CatBoostRegressor, Pool, CatBoostClassifier
from sklearn.model_selection import train_test_split

# %%
drop_cols = ['target_class', 'target_reg']

# %%
X = merged_df_4.drop(drop_cols, axis=1, errors = 'ignore')
y = merged_df_4['target_class'].fillna(0) #предыдущие данные то класс поломки и количество дней имеет корреляцию

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = CatBoostClassifier(random_state=42,
                           thread_count=-1)
model.fit(X_train, y_train,
          eval_set=(X_test, y_test),
          verbose=100, plot=False,
          early_stopping_rounds=100)
# Out:
# Learning rate set to 0.109043
# 0:	learn: 1.7063556	test: 1.7421041	best: 1.7421041 (0)	total: 32.8ms	remaining: 32.8s
# 100:	learn: 0.1021939	test: 0.2174119	best: 0.2174119 (100)	total: 3.36s	remaining: 29.9s
# 200:	learn: 0.0621171	test: 0.1984970	best: 0.1984970 (200)	total: 8.71s	remaining: 34.6s
# 300:	learn: 0.0416700	test: 0.1952702	best: 0.1952702 (300)	total: 14.7s	remaining: 34s
# 400:	learn: 0.0311384	test: 0.1939951	best: 0.1935969 (352)	total: 22.2s	remaining: 33.2s
# 500:	learn: 0.0239722	test: 0.1921519	best: 0.1920162 (471)	total: 29.6s	remaining: 29.5s
# 600:	learn: 0.0192233	test: 0.1929895	best: 0.1914427 (547)	total: 32.8s	remaining: 21.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.1914426662
# bestIteration = 547
#
# Shrink model to first 548 iterations.

# %%
# таблица важности признаков катбуста
fi = model.get_feature_importance(prettified=True)
fi
# Out:
#                 Feature Id  Importances
# 0                max_speed    26.296889
# 1         mean_user_rating    17.211261
# 2              total_stops    16.930289
# 3              mean_rating    14.618362
# 4               min_rating     6.940174
# 5        max_work_duration     4.927181
# 6                 mean_age     2.393371
# 7              sum_user_id     1.955141
# 8     min_deviation_normal     1.601140
# 9               car_rating     0.935455
# 10  mean_user_ride_quality     0.756502
# 11                car_type     0.688836
# 12      mean_work_duration     0.683921
# 13                  riders     0.660207
# 14                   model     0.570018
# 15                 max_age     0.531738
# 16                 min_age     0.455352
# 17       min_work_duration     0.420207
# 18            sum_distance     0.419669
# 19            year_to_work     0.352337
# 20       sum_ride_duration     0.293175
# 21           year_to_start     0.273223
# ...

# %%
#визуализация полученных признаков
feature_importance = model.feature_importances_
sorted_idx = np.argsort(feature_importance)
fig = plt.figure(figsize=(12, 6))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(X.columns)[sorted_idx])
plt.title('Feature Importance');

# %% [markdown]
# **Вывод:** по данным наибольшее влияние оказывает на целевую переменную - максимальная скорость, средний рейтинг водителя, количество остановок, средний рейтинг машины, средний рейтинг машины, минимальный рейтинг машины, максимальная длительность простоя и т.д. Наименьшее влияние оказывает: тип топлива, год начала работы.

# %% [markdown]
# ## Permutation Importance

# %%
from sklearn.inspection import permutation_importance

perm_importance = permutation_importance(model, X_test, y_test, n_repeats=10, random_state=1066)
sorted_idx = perm_importance.importances_mean.argsort()
fig = plt.figure(figsize=(12, 6))
plt.barh(range(len(sorted_idx)), perm_importance.importances_mean[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(X.columns)[sorted_idx])
plt.title('Permutation Importance');

# %% [markdown]
# **Вывод:** наиболее важными признаками являются: максимальная скорость, средний рейтин водителя, средний рейтинг машины, количество остановок, минимальный рейтиг машины, количество водителей, средний возраст водителей.
# Минимальное влияние: модель, средняя длительность простоя, суммарная дистанция.

# %% [markdown]
# По всем данным можно сделать вывод, что следует оставить:
# - max_speed (максимальная скорость),
# - mean_user_rating,
# - total_stops,
# - mean_rating,
# - min_rating,
# - max_work_duration,
# - mean_age,
# - sum_user_id,
# - min_deviation_normal,
# - car_rating,
# - mean_user_ride_quality,
# - car_type

# %% [markdown]
# Создаем датасет с выделенными параметрами.

# %%
# Выбираем определенные столбцы, которые должны остаться в новом датасете
selected_columns = ['max_speed', 'mean_user_rating', 'total_stops', 'mean_rating', 'min_rating', 'max_work_duration',
                    'mean_age', 'sum_user_id', 'min_deviation_normal',
                   'car_rating', 'mean_user_ride_quality', 'car_type']

# Создаем новый датасет, содержащий только выбранные столбцы
new_df = merged_df_4[selected_columns]

# Сохраняем новый датасет в файл
new_df.to_csv('new_dataset.csv', index=False)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   max_speed               2337 non-null   float64
#  1   mean_user_rating        2337 non-null   float64
#  2   total_stops             2337 non-null   int64
#  3   mean_rating             2337 non-null   float64
#  4   min_rating              2337 non-null   float64
#  5   max_work_duration       2337 non-null   int64
#  6   mean_age                2337 non-null   float64
#  7   sum_user_id             2337 non-null   int64
#  8   min_deviation_normal    2337 non-null   float64
#  9   car_rating              2337 non-null   float64
#  10  mean_user_ride_quality  2337 non-null   float64
#  11  car_type                2337 non-null   int64
# dtypes: float64(8), int64(4)
# memory usage: 219.2 KB

# %% [markdown]
# ____
# ____
# ____

# %% [markdown]
# # Домашнее задание 2. Прогноз времени и вида поломки машин. Настройка ML-модели

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — составить тренировочную и валидационную выборки, произвести обучение модели `CatBoostClassifier` на тренировочной части и оценить качество на валидационной.

# %% [markdown]
# ##Обучение первой модели (5 баллов)
#
# 1.   Новый пункт
# 2.   Новый пункт

# %% [markdown]
# 1. Классифицируйте признаки на типы (категориальные, числовые, таргеты).
#
# 2. Выделите в `X` только признаки, а в `Y` — таргет (для задачи классификации).
#
# 3. Сделайте разделение данных на *обучающую* и *валидационную* выборки (не забывайте про воспроизводимость результатов).
#
# 4. Создайте и обучите `CatBoostClassifier` модель (настраивать гиперпараметры сейчас не обязательно).
#
# 5. Проведите оценку вашей модели, используя метрику `accuracy`.
#
#
# <h4> Критерии оценивания </h4>
#
# - По 1 баллу за каждый корректно выполненный пункт.
#
# </div>

# %%
from catboost import CatBoostClassifier, CatBoostRegressor, Pool
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
merged_df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   model                   2337 non-null   object
#  1   car_type                2337 non-null   object
#  2   fuel_type               2337 non-null   object
#  3   car_rating              2337 non-null   float64
#  4   year_to_start           2337 non-null   int64
#  5   riders                  2337 non-null   int64
#  6   year_to_work            2337 non-null   int64
#  7   target_reg              2337 non-null   float64
#  8   target_class            2337 non-null   object
#  9   min_rating              2337 non-null   float64
#  10  mean_rating             2337 non-null   float64
#  11  sum_distance            2337 non-null   float64
#  12  max_speed               2337 non-null   float64
#  13  total_stops             2337 non-null   int64
# ...

# %% [markdown]
# Классифицируйте признаки на типы (категориальные, числовые, таргеты).

# %%
features2drop = ['max_speed', 'mean_user_rating', 'total_stops', 'mean_rating', 'min_rating', 'max_work_duration',
                    'mean_age', 'sum_user_id', 'min_deviation_normal',
                   'car_rating', 'mean_user_ride_quality', 'car_type'] # то, что надо выбросить
targets = ['target_reg', 'target_class'] # таргеты
cat_features = ['car_type'] # категориальные признаки

num_features = ['max_speed','mean_user_rating', 'total_stops', 'mean_rating',
                'min_rating', 'max_work_duration', 'mean_age', 'sum_user_id',
                'min_deviation_normal','car_rating', 'mean_user_ride_quality' ] # числовые признаки

print('Категориальные признаки:', len(cat_features), cat_features)
print('Числовые признаки:', len(num_features), num_features)
print('Целевые переменные', targets)
# Out:
# Категориальные признаки: 1 ['car_type']
# Числовые признаки: 11 ['max_speed', 'mean_user_rating', 'total_stops', 'mean_rating', 'min_rating', 'max_work_duration', 'mean_age', 'sum_user_id', 'min_deviation_normal', 'car_rating', 'mean_user_ride_quality']
# Целевые переменные ['target_reg', 'target_class']

# %% [markdown]
# Выделите в X только признаки, а в Y — таргет (для задачи классификации).

# %%
X = merged_df_5[cat_features + num_features]
y = merged_df_5['target_class'] #предсказание класса поломки - задача классификации

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   car_type                2337 non-null   object
#  1   max_speed               2337 non-null   float64
#  2   mean_user_rating        2337 non-null   float64
#  3   total_stops             2337 non-null   int64
#  4   mean_rating             2337 non-null   float64
#  5   min_rating              2337 non-null   float64
#  6   max_work_duration       2337 non-null   int64
#  7   mean_age                2337 non-null   float64
#  8   sum_user_id             2337 non-null   int64
#  9   min_deviation_normal    2337 non-null   float64
#  10  car_rating              2337 non-null   float64
#  11  mean_user_ride_quality  2337 non-null   float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 219.2+ KB

# %%
X.head()
# Out:
#    car_type   max_speed  mean_user_rating  total_stops  mean_rating  \
# 0   economy  180.855726          8.229885          630     4.737759
# 1   economy  187.862734          7.988506          145     4.480517
# 2  standart  102.382857          7.843103          140     4.768391
# 3  business  172.793237          8.524138          150     3.880920
# 4  standart  203.462289          8.112069          132     4.181149
#
#    min_rating  max_work_duration   mean_age  sum_user_id  \
# 0         0.1                 56  33.511494          170
# 1         0.0                 48  34.988506          174
# 2         0.1                 59  32.839080          173
# 3         0.1                 64  34.977011          170
# 4         0.1                 65  34.298851          171
#
#    min_deviation_normal  car_rating  mean_user_ride_quality
# 0                -9.000        3.78               -0.901190
# 1               -25.088        3.90               14.018105
# ...

# %% [markdown]
# Сделайте разделение данных на обучающую и валидационную выборки (не забывайте про воспроизводимость результатов).

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Создайте и обучите CatBoostClassifier модель (настраивать гиперпараметры сейчас не обязательно).

# %%
model = CatBoostClassifier(random_state=42,
                           thread_count=-1,
                           cat_features = ['car_type'],
                           custom_metric=["Accuracy"])
model.fit(
          X_train,
          y_train,
          eval_set=(X_test, y_test),
          verbose=100, #объем выводимой информации (False — подавляем сообщения).
          plot=False, #
          use_best_model=True,#в результате обучения с ранней остановкой будет возвращаться модель,
                               #полученная на итерации (количеством деревьев) с лучшей метрикой на валидационной выборке.
          early_stopping_rounds=100 #количество интераций до достижения лучщих показателей
          )
# Out:
# Learning rate set to 0.109043
# 0:	learn: 1.6918855	test: 1.7204710	best: 1.7204710 (0)	total: 102ms	remaining: 1m 41s
# 100:	learn: 0.1095711	test: 0.2150441	best: 0.2150441 (100)	total: 9.26s	remaining: 1m 22s
# 200:	learn: 0.0660726	test: 0.1954798	best: 0.1954798 (200)	total: 15.2s	remaining: 1m
# 300:	learn: 0.0458412	test: 0.1909559	best: 0.1908008 (296)	total: 21.1s	remaining: 49s
# 400:	learn: 0.0337163	test: 0.1900605	best: 0.1896626 (397)	total: 26.2s	remaining: 39.2s
# 500:	learn: 0.0263928	test: 0.1902344	best: 0.1895251 (423)	total: 32.9s	remaining: 32.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.1895250566
# bestIteration = 423
#
# Shrink model to first 424 iterations.

# %%
predictions = model.predict(X_test) #предсказания модели на тестовых данных

accuracy = accuracy_score(y_test, predictions) #вычисление точности

print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.9344729344729344

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# Модель для предсказывая количества дней до поломки - задача регрессии

# %%
X1 = merged_df_5[cat_features + num_features]
y1 = merged_df_5['target_reg'] #предсказание дней до поломки

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.3, random_state=42)

# %%
model2 = CatBoostRegressor(
    random_seed=42,
    thread_count=-1,
    cat_features = ['car_type'],
    custom_metric=["RMSE"]
    )

# %%
train_pool = Pool(X1_train, y1_train, cat_features= ['car_type'])
test_pool = Pool(X1_test, y1_test, cat_features= ['car_type'])

# %%
model2.fit(
      train_pool,
      eval_set=test_pool,
      verbose=100,
      use_best_model=True,
      plot=False,
      early_stopping_rounds=100 #количество интераций до достижения лучщих показателей
          )
# Out:
# Learning rate set to 0.055007
# 0:	learn: 17.2034722	test: 17.0207651	best: 17.0207651 (0)	total: 7.57ms	remaining: 7.57s
# 100:	learn: 8.2766710	test: 10.0251618	best: 10.0251618 (100)	total: 345ms	remaining: 3.07s
# 200:	learn: 7.1934671	test: 9.8081855	best: 9.8081507 (199)	total: 689ms	remaining: 2.74s
# 300:	learn: 6.4248523	test: 9.7216797	best: 9.7127910 (281)	total: 1.02s	remaining: 2.36s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 9.712791
# bestIteration = 281
#
# Shrink model to first 282 iterations.

# %%
from sklearn.metrics import mean_squared_error

predictions = model2.predict(X1_test) # Предсказания модели на тестовых данных

rmse = mean_squared_error(y1_test, predictions, squared=False) # Вычисление RMSE

print(f'RMSE: {rmse}')
# Out:
# RMSE: 9.712791029279279

# %% [markdown]
# # Дополнительное задание. Визуализация прогнозов, ошибок модели и важности признаков

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — визуализировать результаты прогнозирования, ошибки модели и важность признаков для лучшего понимания и анализа модели.

# %% [markdown]
# ## Визуализация (5 баллов)

# %% [markdown]
#
# 1. Визуализируйте важность признаков встроенным методом в `CatBoost`  (помните, что не стоит сильно доверять этому рейтингу важности, т. к. для сильно скоррелированных признаков важность делится пополам — оба признака могут улететь вниз).
#
# 2. Постройте `waterfall_plot` из библиотеки `SHAP` (подробнее во втором ноутбуке из полезных ссылок ниже).
#
# 3. Постройте `classification_report` из библиотеки `scikit-learn`.
#
# 4. Постройте и визуализируйте матрицу смежности (`confusion_matrix`), посмотрите, в каких классах модель больше всего ошибается.
#
# 5. Для каждого графика/примененного метода проинтерпретируйте результаты и сделайте выводы.
#
#
# <h4> Критерии оценивания </h4>
#
# - По 1 баллу за каждый корректно выполненный пункт.
#
# </div>
#
# <div class="alert alert-success">
#
# Визуализация может помочь даже после того, как мы **уже обучили** какую-нибудь модель. Например:
#
# - Понять, что мешает модели или чего не хватает, чтобы не допускать ошибки.
# - Сделать выводы, как можно улучшить точность в последующих экспериментах.
# - Визуализировать ошибки модели.
# - Отсеять лишние признаки.
# - Найти идеи для новых признаков.
# - Все зависит от типа ваших данных.
#
# <h3> Полезные источники </h3>
#
# - Занятие про визуализацию и Seaborn.
# - Занятие про продвинутую визуализацию и анализ ошибок модели.
#
# </div>

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# Визуализируйте важность признаков встроенным методом в CatBoost (помните, что не стоит сильно доверять этому рейтингу важности, т. к. для сильно скоррелированных признаков важность делится пополам — оба признака могут улететь вниз).

# %%
#визуализация полученных признаков
feature_importance = model.feature_importances_
sorted_idx = np.argsort(feature_importance)
fig = plt.figure(figsize=(12, 6))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center')
plt.yticks(range(len(sorted_idx)), np.array(X.columns)[sorted_idx])
plt.title('Важность признаков для модели предсказания типа поломки')
# Out:
# Text(0.5, 1.0, 'Важность признаков для модели предсказания типа поломки')

# %% [markdown]
# Вывод: Набольшее влияние на модель параметры - max_speed, mean_user_rating, total_stops, mean_rating.

# %%
#визуализация полученных признаков
feature_importance = model2.feature_importances_
sorted_idx = np.argsort(feature_importance)
fig = plt.figure(figsize=(12, 6))
plt.barh(range(len(sorted_idx)), feature_importance[sorted_idx], align='center', color='skyblue')
plt.yticks(range(len(sorted_idx)), np.array(X.columns)[sorted_idx])
plt.title('Важность признаков для модели предсказания количества дней до поломки')
# Out:
# Text(0.5, 1.0, 'Важность признаков для модели предсказания количества дней до поломки')

# %% [markdown]
# Вывод: Набольшее влияние на модель параметры - max_speed, mean_user_rating, total_stops, mean_rating.

# %% [markdown]
# ---

# %% [markdown]
# Постройте waterfall_plot из библиотеки SHAP (подробнее во втором ноутбуке из полезных ссылок ниже).

# %%
# !pip install shap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 6.0 MB/s eta 0:00:00
# ...

# %%
import numpy as np

# %%
import shap
from catboost import CatBoostClassifier
from catboost import Pool

# Создание объекта для объяснения модели CatBoostClassifier с помощью SHAP
explainer = shap.TreeExplainer(model)

# Создание датасета для объяснения (ваш X_test и y_test должны быть определены заранее)
val_dataset = Pool(data=X_test, label=y_test, cat_features=['car_type'])

# Получение значений SHAP для объяснения модели
shap_values = explainer.shap_values(val_dataset)

# Визуализация значений SHAP
shap.summary_plot(shap_values, X_test, max_display=35)

# %% [markdown]
# ВЫВОД: Наибольшее влияние на работу модели оказывает max_speed, mean_rating,mean_user.

# %% [markdown]
# ---

# %% [markdown]
# Постройте classification_report из библиотеки scikit-learn.

# %%
from sklearn.metrics import classification_report

# Получение предсказаний модели на тестовом наборе данных
y_pred = model.predict(X_test)

# Создание classification report
report = classification_report(y_test, y_pred)

print(report)
# Out:
#                  precision    recall  f1-score   support
#
#     another_bug       0.96      0.99      0.97        75
#       break_bug       1.00      1.00      1.00        79
#     electro_bug       1.00      1.00      1.00        80
#    engine_check       0.91      0.96      0.93        82
#     engine_fuel       0.84      0.79      0.81        90
# engine_ignition       0.85      0.83      0.84        92
# engine_overheat       0.91      0.94      0.92        71
#      gear_stick       1.00      1.00      1.00        82
#     wheel_shake       0.98      0.94      0.96        51
#
#        accuracy                           0.93       702
#       macro avg       0.94      0.94      0.94       702
#    weighted avg       0.93      0.93      0.93       702

# %% [markdown]
# ВЫВОД: Данные позволяют судить, какие из данных лучще предсказываются, какие хуже. В данном случае хорошо определяется класс - break_bug, electro_bug,  gear_stick.
# Хуже: engine_fuel, engine_ignition.

# %% [markdown]
# ---

# %% [markdown]
# Постройте и визуализируйте матрицу смежности (confusion_matrix), посмотрите, в каких классах модель больше всего ошибается.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Получение предсказаний модели на тестовом наборе данных
y_pred = model.predict(X_test)

# Построение матрицы смежности
cm = confusion_matrix(y_test, y_pred)

# Визуализация матрицы смежности с помощью тепловой карты
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=model.classes_, yticklabels=model.classes_)
plt.xlabel('Предскание')
plt.ylabel('Актуальность')
plt.title('Матрица смежности')
plt.show()

# %% [markdown]
# ВЫВОД: Чаще всего модель ошибается в предсказании классов поломок: fuel, chek, ignition.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# # Домашнее задание 3. Оптимизация. Тюнинг гиперпараметров с помощью `Optuna`

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — улучшить качество предсказания, произведя подбор гиперпараметров для модели с помощью `Optuna`.

# %% [markdown]
# ## Подбор гиперпараметров (3 балла)

# %% [markdown]
# 1. Напишите `objective` функцию и запустите `Optuna`.
# 2. Подберите гиперпараметры для `CatBoostClassifier` (минимум 3).
# 3. Обучите модель с новыми гиперпараметрами, сравните качество и сделайте выводы.
#
#
# <h4> Критерии оценивания </h4>
#
# - 1 балл за каждый корректно выполненный пункт.
#
# </div>

# %%
# !pip install optuna
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.0/233.0 kB 25.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 8.7 MB/s eta 0:00:00
# ...

# %%
import optuna
from catboost import CatBoostClassifier
from sklearn.model_selection import cross_val_score

# %%
merged_df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   model                   2337 non-null   object
#  1   car_type                2337 non-null   object
#  2   fuel_type               2337 non-null   object
#  3   car_rating              2337 non-null   float64
#  4   year_to_start           2337 non-null   int64
#  5   riders                  2337 non-null   int64
#  6   year_to_work            2337 non-null   int64
#  7   target_reg              2337 non-null   float64
#  8   target_class            2337 non-null   object
#  9   min_rating              2337 non-null   float64
#  10  mean_rating             2337 non-null   float64
#  11  sum_distance            2337 non-null   float64
#  12  max_speed               2337 non-null   float64
#  13  total_stops             2337 non-null   int64
# ...

# %%
train = merged_df_5


cat_features = ["model", "car_type", "fuel_type"]  # Выделяем категориальные признаки
targets = ["target_class", "target_reg"]
features2drop = ["car_id"]  # эти фичи будут удалены

# Отбираем итоговый набор признаков для использования моделью
filtered_features = [i for i in train.columns if (i not in targets)]
num_features = [i for i in filtered_features if i not in cat_features]

# %%
print(filtered_features)
# Out:
# ['model', 'car_type', 'fuel_type', 'car_rating', 'year_to_start', 'riders', 'year_to_work', 'min_rating', 'mean_rating', 'sum_distance', 'max_speed', 'total_stops', 'sum_ride_duration', 'min_deviation_normal', 'mean_user_ride_quality', 'sum_user_id', 'mean_user_rating', 'min_age', 'mean_age', 'max_age', 'min_work_duration', 'mean_work_duration', 'max_work_duration']

# %%
print(num_features)
# Out:
# ['car_rating', 'year_to_start', 'riders', 'year_to_work', 'min_rating', 'mean_rating', 'sum_distance', 'max_speed', 'total_stops', 'sum_ride_duration', 'min_deviation_normal', 'mean_user_ride_quality', 'sum_user_id', 'mean_user_rating', 'min_age', 'mean_age', 'max_age', 'min_work_duration', 'mean_work_duration', 'max_work_duration']

# %%
# !pip install optuna catboost -q

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import KFold, train_test_split

# %%
def fit_catboost(trial, train, val):
    X_train, y_train = train
    X_val, y_val = val

    param = {
        'iterations' : 400, # Можно не перебирать, есть Early-Stopping
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.01),
        "l2_leaf_reg": trial.suggest_int("l2_leaf_reg", 2, 50),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.8),

        "auto_class_weights": trial.suggest_categorical("auto_class_weights", ["SqrtBalanced", "Balanced", "None"]),
        "depth": trial.suggest_int("depth", 3, 9),

        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical("bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]),
        "used_ram_limit": "14gb",
        "eval_metric": "Accuracy", # Тоже стоит заранее определиться
    }


    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 20)

    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)


    clf = CatBoostClassifier(
        **param,
        thread_count=-1,
        random_seed=42,
        cat_features=cat_features,
    )

    clf.fit(
        X_train,
        y_train,
        eval_set=(X_val, y_val),
        verbose=0,
        plot=False,
        early_stopping_rounds=5,
    )

    y_pred = clf.predict(X_val)
    return clf, y_pred

# %%
import optuna

# %%
from sklearn.metrics import accuracy_score

# %%
def objective(trial, return_models=False):
    n_splits = 3
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    X_train = train[filtered_features].drop(targets, axis=1, errors="ignore")
    y_train = train["target_class"]

    scores, models = [], []

    for train_idx, valid_idx in kf.split(X_train):
        train_data = X_train.iloc[train_idx, :], y_train.iloc[train_idx]
        valid_data = X_train.iloc[valid_idx, :], y_train.iloc[valid_idx]

        # Подаем trials для перебора
        model, y_pred = fit_catboost(trial, train_data, valid_data) # Определили выше
        scores.append(accuracy_score(y_pred, valid_data[1]))
        models.append(model)
        break


    result = np.mean(scores)

    if return_models:
        return result, models
    else:
        return result

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective,
               n_trials=600,
               n_jobs = -1,
               show_progress_bar=True,)
# Out:
# [I 2024-07-19 09:57:08,021] A new study created in memory with name: no-name-80e8dc74-7a8f-47a4-907f-2142be758af8
#   0%|          | 0/600 [00:00<?, ?it/s]
# [I 2024-07-19 09:57:08,485] Trial 0 finished with value: 0.8729139922978177 and parameters: {'learning_rate': 0.004642601246584992, 'l2_leaf_reg': 28, 'colsample_bylevel': 0.5183592307504026, 'auto_class_weights': 'None', 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.016299187667062}. Best is trial 0 with value: 0.8729139922978177.
# [I 2024-07-19 09:57:08,880] Trial 2 finished with value: 0.8690629011553274 and parameters: {'learning_rate': 0.007098644953723099, 'l2_leaf_reg': 3, 'colsample_bylevel': 0.7667851219188194, 'auto_class_weights': 'Balanced', 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7404957233188357}. Best is trial 0 with value: 0.8729139922978177.
# ...

# %%
print("Best trial: score {}, params {}".format(study.best_trial.value, study.best_trial.params))
# Out:
# Best trial: score 0.944801026957638, params {'learning_rate': 0.00430363817169137, 'l2_leaf_reg': 4, 'colsample_bylevel': 0.7302167351031017, 'auto_class_weights': 'SqrtBalanced', 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.155779099515295}

# %% [markdown]
# Обучим итоговые модели уже на них

# %%
valid_scores, models = objective(
    optuna.trial.FixedTrial(study.best_params),
    return_models=True,
)

# %%
valid_scores, len(models)
# Out:
# (0.944801026957638, 1)

# %% [markdown]
# Чтобы посмотреть всю историю обучения, можно вывести ее в виде датафрейма

# %%
trials_df = study.trials_dataframe().sort_values('value', ascending=False)
trials_df.head(3)
# Out:
#      number     value             datetime_start          datetime_complete  \
# 181     181  0.944801 2024-07-19 10:13:39.831268 2024-07-19 10:14:26.028860
# 541     541  0.940950 2024-07-19 11:58:39.210061 2024-07-19 11:59:25.544522
# 410     410  0.940950 2024-07-19 11:13:33.266850 2024-07-19 11:14:03.456330
#
#                   duration params_auto_class_weights  \
# 181 0 days 00:00:46.197592              SqrtBalanced
# 541 0 days 00:00:46.334461              SqrtBalanced
# 410 0 days 00:00:30.189480              SqrtBalanced
#
#      params_bagging_temperature params_boosting_type params_bootstrap_type  \
# 181                    8.155779              Ordered              Bayesian
# 541                    9.387376              Ordered              Bayesian
# 410                    5.294206              Ordered              Bayesian
#
#      params_colsample_bylevel  params_depth  params_l2_leaf_reg  \
# 181                  0.730217             9                   4
# ...

# %%
# История изменения от числа испытаний
optuna.visualization.plot_optimization_history(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Зависимость в разрере по параметрам
params = ['l2_leaf_reg', 'colsample_bylevel', 'bagging_temperature', 'depth', 'bootstrap_type', 'subsample']
optuna.visualization.plot_slice(study,
                                params=params,
                                target_name = 'accuracy_score')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1. l2_leaf_reg: параметр, отвечающий за регуляризацию модели (L2 регуляризация). Значение около 0 - оптимально.
# 2. colsample_bylevel: параметр, определяющий долю признаков, используемых при построении каждого уровня дерева: 0,2 - оптимально. 20% признаков (столбцов) будет использоваться. Следовательно, как было показано выше из набора в 23 примерно признаков, только примерно 3-4 имеют влияние на точность, остальными можно принебречь.
# 3. bagging_temperature: параметр, связанный с бэггингом (случайный выбор данных для обучения каждого базового алгоритма): около 0 оптимально.
# 4. depth: параметр, указывающий максимальную глубину дерева решений: около 8 - оптимально
# 5. bootstrap_type: параметр, определяющий тип бутстрапа (способ формирования обучающих подвыборок): Байсовское - меньше разброс.
# 6. subsample: параметр, определяющий долю случайно выбранных образцов для обучения каждого базового алгоритма: оптимально -1.

# %%
# Важность параметров
optuna.visualization.plot_param_importances(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Наибольшее влияние оказывает colsample_bylevel. Следовательно, именно выбор правильный признаков окажут наибольшее влияние на работу модели.

# %% [markdown]
# # **Подберите гиперпараметры для CatBoostClassifier (минимум 3).**

# %%
X = merged_df_5[cat_features + num_features]
y = merged_df_5['target_class'] #предсказание класса поломки - задача классификации

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-f55f6ff0d14b> in <cell line: 1>()
# ----> 1 X = merged_df_5[cat_features + num_features]
#       2 y = merged_df_5['target_class'] #предсказание класса поломки - задача классификации
#       3
#       4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#
# NameError: name 'num_features' is not defined

# %%
cat_features = ["model", "car_type", "fuel_type"]  # Выделяем категориальные признаки

# %%
merged_df_5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   model                   2337 non-null   object
#  1   car_type                2337 non-null   object
#  2   fuel_type               2337 non-null   object
#  3   car_rating              2337 non-null   float64
#  4   year_to_start           2337 non-null   int64
#  5   riders                  2337 non-null   int64
#  6   year_to_work            2337 non-null   int64
#  7   target_reg              2337 non-null   float64
#  8   target_class            2337 non-null   object
#  9   min_rating              2337 non-null   float64
#  10  mean_rating             2337 non-null   float64
#  11  sum_distance            2337 non-null   float64
#  12  max_speed               2337 non-null   float64
#  13  total_stops             2337 non-null   int64
# ...

# %%
# Создаем модель CatBoostClassifier с заданными параметрами
model = CatBoostClassifier(random_state=42,
                           thread_count=-1,
                           cat_features=cat_features,
                           custom_metric=["Accuracy"]
                           )

model.fit(X_train, y_train,
          eval_set=(X_test, y_test),
          verbose=100,
          plot=False,
          use_best_model=True,
          early_stopping_rounds=100)
# Out:
# Learning rate set to 0.109043
# 0:	learn: 1.6784096	test: 1.7078013	best: 1.7078013 (0)	total: 97.2ms	remaining: 1m 37s
# 100:	learn: 0.1096731	test: 0.2169319	best: 0.2169319 (100)	total: 12s	remaining: 1m 46s
# 200:	learn: 0.0687271	test: 0.2029577	best: 0.2028665 (196)	total: 23.8s	remaining: 1m 34s
# 300:	learn: 0.0493645	test: 0.1949395	best: 0.1948946 (295)	total: 35.8s	remaining: 1m 23s
# 400:	learn: 0.0355532	test: 0.1898966	best: 0.1897341 (399)	total: 46.7s	remaining: 1m 9s
# 500:	learn: 0.0271385	test: 0.1888362	best: 0.1886809 (497)	total: 57.9s	remaining: 57.7s
# 600:	learn: 0.0215808	test: 0.1899463	best: 0.1886661 (504)	total: 1m 9s	remaining: 46.3s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.1886661029
# bestIteration = 504
#
# Shrink model to first 505 iterations.

# %%
predictions = model.predict(X_test) #предсказания модели на тестовых данных

accuracy = accuracy_score(y_test, predictions) #вычисление точности

print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.9387464387464387

# %%
# Создаем модель CatBoostClassifier с заданными параметрами
model_2 = CatBoostClassifier(random_state=42,
                           thread_count=-1,
                           cat_features=cat_features,
                           custom_metric=["Accuracy"],
                           depth=8,
                           bootstrap_type='Bayesian',
                           l2_leaf_reg=0.01)

model_2.fit(X_train, y_train,
          eval_set=(X_test, y_test),
          verbose=100,
          plot=False,
          use_best_model=True,
          early_stopping_rounds=100)
# Out:
# 0:	learn: 2.0022207	test: 2.0114995	best: 2.0114995 (0)	total: 162ms	remaining: 2m 42s
# 100:	learn: 0.1606599	test: 0.2662346	best: 0.2662346 (100)	total: 16.9s	remaining: 2m 30s
# 200:	learn: 0.0601331	test: 0.2025133	best: 0.2025133 (200)	total: 35.1s	remaining: 2m 19s
# 300:	learn: 0.0255780	test: 0.1866800	best: 0.1866800 (300)	total: 54.5s	remaining: 2m 6s
# 400:	learn: 0.0124685	test: 0.1834060	best: 0.1829363 (386)	total: 1m 11s	remaining: 1m 47s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.1829363097
# bestIteration = 386
#
# Shrink model to first 387 iterations.

# %%
predictions_2 = model_2.predict(X_test) #предсказания модели на тестовых данных

accuracy_2 = accuracy_score(y_test, predictions_2) #вычисление точности

print(f'Accuracy: {accuracy_2}' )
# Out:
# Accuracy: 0.9430199430199431

# %% [markdown]
# Без удаление незначащих признаков.
#
# Весрия предыдущая: 0.9387464387464387
#
# Новое показание: 0.9430199430199431

# %% [markdown]
# ВЫВОД: Данный подход позволяет повысить точность работы модели. Скорее всего его стоит использовать, когда уже другие методы попробованы, а точность не удовлетворяет.

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ### Общая информация по `Optuna`

# %% [markdown]
# #### Ключевые особенности <code>Optuna</code>

# %% [markdown]
# - Легковесность и универсальность — можно подбирать оптимальные параметры под любые функции и метрики.
# - SOTA-алгоритмы, адаптированные для поиска гиперпараметров.
# - Параллелизация и различные методы прунинга.
# - Встроенная визуализация.
# - Интеграция со множеством популярных библиотек (бустинги, sklearn, PyTorch, W&B и другие).
#
# Разберем Optuna по частям, чтобы понять, как ее использовать.

# %% [markdown]
# #### <code>Study</code>: оптимизация, базирующаяся на <code>Objective</code> функции

# %% [markdown]
# В `Objective`-функцию нужно написать код подсчета метрики, которую возвращаем. `Objective` вызывается Optuna много раз для подбора лучших параметров.
# ```python
# def objective(trial, ...):
#     # calculate score...
#     return score
# ```
#
# <h4> <code>Trial</code> — одно выполнение <code>Objective</code>-функции</h4>
#
# В `trial`-объекте мы передаем параметры для «перебора», используя для каждого типа свой метод. Например:
#
# ```python
# # метод `suggest_float` показывает, что перебираем `float` значения, от 0 и до 1.5 границы
# param = trial.suggest_float('param', 0, 1.5)
#
# # Категориальное значение
# loss_function = trial.suggest_categorical('loss', ['Logloss', 'CrossEntropy'])
#
# # Целочисленное значение
# depth = trial.suggest_int('depth', 5, 8)
#
# # Равномерное распределение
# learning_rate = trial.suggest_uniform('learning_rate', 0.0, 1.0)
# ```

# %% [markdown]
# #### `Study` parameters

# %% [markdown]
# Инициализируем объект `study`, который начнет перебор и сохранит в себе историю результатов.
# Если мы стараемся увеличить метрику, а не уменьшить ошибку, то используем `create_study(direction='maximize')`.
# ```python
# study = optuna.create_study()
# study.optimize(objective, n_trials=10)
# ```

# %% [markdown]
# <div class="alert alert-info">
#
# В [`Optuna`](https://optuna.readthedocs.io/en/stable/index.html) реализовано несколько методов (`sampler`) подбора параметров (в том числе классические):
# * `GridSampler`
# * `RandomSampler`
# * `Tree-Structed Parzen Estimator` (`TPESampler` — самый популярный, дефолтный)
# * `BruteForceSampler`
# * [Другие 4 метода](https://optuna.readthedocs.io/en/stable/reference/samplers/index.html#module-optuna.samplers) (можно написать собственный семплер)

# %% [markdown]
# ### Советы по перебору параметров

# %% [markdown]
# - Иметь понимание важности параметров.
# - Число `iterations` лучше взять с запасом и зафиксировать, при этом ограничив через `early_stopping_rounds`.
# - Подсмотреть или чувствовать диапазоны и шаг значений.
# - Исключить то, что перебирать не нужно (`random_seed` , `eval_metric`, `thread_count` и прочее).
# - Используйте информацию с прошлых попыток.

# %% [markdown]
# # Домашнее задание 4. Блендинг

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — улучшить качество предсказания, объединив несколько моделей вместе методом блендинга.

# %% [markdown]
# ## Задание 6. Блендинг (10 баллов)

# %% [markdown]
# 1. Построить и обучить модели:
#     - `CatBoostClassifier`,
#     - `LightGBMClassifier (goss)`,
#     - `XGBoostClassifier (dart)`,
#     - `RandomForestClassifier`.
# 2. Сделать предсказания каждой моделью, оценить качество.
# 3. Реализовать блендинг двумя способами, оценить качество и сравнить с предыдущим пунктом:
#     - `Hard Voting` —  метод, при котором делаем голосование всех моделей и выбираем самый популярный класс.
#     - `Soft Voting` —  метод, при котором мы складываем вероятности предсказания всех моделей по каждому классу и потом выбираем самый класс с максимальной суммой.
#
# <h4> Критерии оценивания </h4>
#
# - Обучены 4 модели — 1 балл за каждую обученную модель, всего 4 балла.
# - Для модели проведен подбор гиперпараметров — 0,5 балла за каждый параметр, всего 2 балла.
# - Сделаны предсказания каждой модели и оценено качество — 1 балл.
# - Реализован `Hard Voting` — 1 балл.
# - Реализован `Soft Voting` — 1 балл.
# - Сделаны выводы — 1 балл.
#
# </div>

# %%
X = merged_df_5[cat_features + num_features]
y = merged_df_5['target_class'] #предсказание класса поломки - задача классификации

# %%
cat_features = ["model", "car_type", "fuel_type"]  # Выделяем категориальные признаки

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   model                   2337 non-null   object
#  1   car_type                2337 non-null   object
#  2   fuel_type               2337 non-null   object
#  3   max_speed               2337 non-null   float64
#  4   mean_user_rating        2337 non-null   float64
#  5   total_stops             2337 non-null   int64
#  6   mean_rating             2337 non-null   float64
#  7   min_rating              2337 non-null   float64
#  8   max_work_duration       2337 non-null   int64
#  9   mean_age                2337 non-null   float64
#  10  sum_user_id             2337 non-null   int64
#  11  min_deviation_normal    2337 non-null   float64
#  12  car_rating              2337 non-null   float64
#  13  mean_user_ride_quality  2337 non-null   float64
# ...

# %%
### Заменим категориальные признаки на числовые значения
cat_cols = ["model", "car_type", "fuel_type"]
for col in cat_cols:
    X[col] = X[col].replace(np.unique(X[col]), np.arange(X[col].nunique()))
    X[col] = X[col].astype("category")

X.head()
# Out:
#   model car_type fuel_type  car_rating  year_to_start  riders  year_to_work  \
# 0     8        1         1        3.78           2015   76163          2021
# 1    23        1         1        3.90           2015   78218          2021
# 2    16        3         1        6.30           2012   23340          2017
# 3    12        0         1        4.04           2011    1263          2020
# 4    16        3         1        4.70           2012   26428          2017
#
#    min_rating  mean_rating  sum_distance  ...  min_deviation_normal  \
# 0         0.1     4.737759  1.214131e+07  ...                -9.000
# 1         0.0     4.480517  1.803909e+07  ...               -25.088
# 2         0.1     4.768391  1.588366e+07  ...               -12.400
# 3         0.1     3.880920  1.651883e+07  ...               -12.691
# 4         0.1     4.181149  1.398317e+07  ...               -20.907
#
#    mean_user_ride_quality  sum_user_id  mean_user_rating  min_age   mean_age  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # **CatBoostClassifier**

# %%
# Создаем модель CatBoostClassifier с заданными параметрами
cat_model = CatBoostClassifier(random_state=42,
                           thread_count=-1,
                           cat_features=cat_features,
                           custom_metric=["Accuracy"],
                           depth=8,
                           bootstrap_type='Bayesian',
                           l2_leaf_reg=0.01)

cat_model.fit(X_train, y_train,
          eval_set=(X_test, y_test),
          verbose=100,
          plot=False,
          use_best_model=True,
          early_stopping_rounds=100)
# Out:
# 0:	learn: 2.0360858	test: 2.0435749	best: 2.0435749 (0)	total: 45ms	remaining: 45s
# 100:	learn: 0.1618430	test: 0.2618258	best: 0.2618258 (100)	total: 12.7s	remaining: 1m 52s
# 200:	learn: 0.0620782	test: 0.1982297	best: 0.1981616 (199)	total: 26.1s	remaining: 1m 43s
# 300:	learn: 0.0272294	test: 0.1828877	best: 0.1828877 (300)	total: 39.5s	remaining: 1m 31s
# 400:	learn: 0.0133064	test: 0.1816427	best: 0.1804676 (347)	total: 53.3s	remaining: 1m 19s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.1804675927
# bestIteration = 347
#
# Shrink model to first 348 iterations.

# %%
predictions =cat_model.predict(X_test) #предсказания модели на тестовых данных

accuracy = accuracy_score(y_test, predictions) #вычисление точности

print(f'Accuracy: {accuracy}' )
# Out:
# Accuracy: 0.9401709401709402

# %%
submit = pd.DataFrame({"target": cat_model.predict(X_test).reshape(-1)})
submit.to_csv("/content/catboost_info/catboost_preds.csv", index=False)
submit.head()
# Out:
#             target
# 0      engine_fuel
# 1      electro_bug
# 2  engine_overheat
# 3  engine_ignition
# 4  engine_ignition

# %% [markdown]
# # **LightGBMClassifier (goss)**

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 702 entries, 1720 to 1887
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   model                   702 non-null    category
#  1   car_type                702 non-null    category
#  2   fuel_type               702 non-null    category
#  3   max_speed               702 non-null    float64
#  4   mean_user_rating        702 non-null    float64
#  5   total_stops             702 non-null    int64
#  6   mean_rating             702 non-null    float64
#  7   min_rating              702 non-null    float64
#  8   max_work_duration       702 non-null    int64
#  9   mean_age                702 non-null    float64
#  10  sum_user_id             702 non-null    int64
#  11  min_deviation_normal    702 non-null    float64
#  12  car_rating              702 non-null    float64
#  13  mean_user_ride_quality  702 non-null    float64
# ...

# %%
from lightgbm import LGBMClassifier

# %%
params_lgbm = {
    "num_leaves": 200,
    "num_iterations": 1500,
    # "max_depth": 7,
    "min_child_samples": 2073,
    "learning_rate": 0.0051,
    "min_data_in_leaf": 10,
    "feature_fraction": 0.99,
    "boosting_type": 'goss',
    'reg_alpha' : 5.0,
    'reg_lambda' : 5.0,
    'early_stopping_rounds': 100,
    'verbose': 150,
    'objective': 'multiclass',
    'metric': 'multi_logloss',
}

lgbm_model = LGBMClassifier(**params_lgbm)

# %%
lgbm_model.fit(
    X_train,
    y_train,
    eval_set=[(X_test, y_test)],
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# Выходные данные были обрезаны до нескольких последних строк (5000).
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 9 and depth = 5
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 2
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
predictions_2 =lgbm_model.predict(X_test) #предсказания модели на тестовых данных

accuracy_2 = accuracy_score(y_test, predictions_2) #вычисление точности

print(f'Accuracy: {accuracy_2}' )
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.99, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.99
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=2073 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
# Accuracy: 0.9387464387464387

# %%
submit = pd.DataFrame({"target": lgbm_model.predict(X_test).reshape(-1)})
submit.to_csv("/content/catboost_info/lgbm_preds.csv", index=False)
submit.head()
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.99, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.99
# [LightGBM] [Warning] min_data_in_leaf is set=10, min_child_samples=2073 will be ignored. Current value: min_data_in_leaf=10
# [LightGBM] [Warning] Found boosting=goss. For backwards compatibility reasons, LightGBM interprets this as boosting=gbdt, data_sample_strategy=goss.To suppress this warning, set data_sample_strategy=goss instead.
#             target
# 0  engine_overheat
# 1      electro_bug
# 2  engine_overheat
# 3  engine_ignition
# 4  engine_ignition

# %% [markdown]
# ## **XGBoostClassifier (dart)**

# %%
X_test.head(2)
# Out:
#      model car_type fuel_type  car_rating  year_to_start  riders  \
# 1720    25        2         0        4.28           2017  114851
# 2025    23        1         1        5.00           2015   87354
#
#       year_to_work  min_rating  mean_rating  sum_distance  ...  \
# 1720          2020         0.1     4.140287  1.163474e+07  ...
# 2025          2018         0.0     4.049598  1.797655e+07  ...
#
#       min_deviation_normal  mean_user_ride_quality  sum_user_id  \
# 1720               -26.601               -4.157663          148
# 2025               -24.584                0.696680          171
#
#       mean_user_rating  min_age   mean_age  max_age  min_work_duration  \
# 1720          9.167241       21  33.362069       53                  1
# 2025          7.975862       18  34.091954       56                  1
#
#       mean_work_duration  max_work_duration
# 1720           27.235294                 60
# 2025           28.147059                 48
#
# [2 rows x 23 columns]

# %%
import xgboost as xgb

# %%
params_xgb_dart = {
    "eta": 0.05,
    "max_depth": 5,
    "subsample": 0.7,
    "colsample_bytree": 0.7,
    'gamma': .01,
    'reg_lambda' : 0.1,
    'reg_alpha' : 0.5,
    "objective": "reg:linear",
    "eval_metric": "mae",
    'tree_method' : 'hist', # Supported tree methods for cat fs are gpu_hist, approx, and hist.
    'enable_categorical' : True,
    'booster': 'dart', # Specify booster as dart for XGBoost with DART
}
xgb_model_dart = xgb.XGBRegressor(**params_xgb_dart)

# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder

# Преобразование строковой целевой переменной в числовой формат
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Обучение модели XGBoost

xgb_model_dart.fit(
    X_train,
    y_train_encoded,
    eval_set=[(X_train, y_train_encoded), (X_test, y_test_encoded)],
    early_stopping_rounds=100,
    verbose=25,
)

print('best_iteration', xgb_model_dart.best_iteration)
# Out:
# [0]	validation_0-mae:2.15980	validation_1-mae:2.05652
# /usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [00:57:04] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# [25]	validation_0-mae:0.88414	validation_1-mae:0.94251
# [50]	validation_0-mae:0.43455	validation_1-mae:0.55709
# [75]	validation_0-mae:0.25651	validation_1-mae:0.41191
# [99]	validation_0-mae:0.20507	validation_1-mae:0.37041
# best_iteration 98

# %%
predictions_3 =xgb_model_dart.predict(X_test) #предсказания модели на тестовых данных

# %%
print(y_train_encoded.shape)
# Out:
# (1635,)

# %%
print(y_test_encoded.shape)
# Out:
# (702,)

# %%
submit = pd.DataFrame({"target": xgb_model_dart.predict(X_test).reshape(-1)})
submit.to_csv("/content/catboost_info/xgb_model_dart.csv", index=False)
submit.head()
# Out:
#      target
# 0  5.050059
# 1  2.017036
# 2  5.982681
# 3  4.628701
# 4  4.910719

# %% [markdown]
# # **RandomForestClassifier.**

# %%
from sklearn.ensemble import RandomForestClassifier

params_rf = {
    'n_estimators': 100,
    'max_depth': 10,
    'min_samples_split': 2,
    'min_samples_leaf': 1,
    'max_features': 'auto',
    'random_state': 42
}

rf_model = RandomForestClassifier(**params_rf)
rf_model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(
# RandomForestClassifier(max_depth=10, max_features='auto', random_state=42)

# %%
predictions_4 =rf_model.predict(X_test) #предсказания модели на тестовых данных

accuracy_4 = accuracy_score(y_test, predictions_4) #вычисление точности

print(f'Accuracy: {accuracy_4}' )
# Out:
# Accuracy: 0.9358974358974359

# %%
submit = pd.DataFrame({"target": rf_model.predict(X_test).reshape(-1)})
submit.to_csv("/content/catboost_info/rf_model.csv", index=False)
submit.head()
# Out:
#             target
# 0      engine_fuel
# 1      electro_bug
# 2  engine_overheat
# 3  engine_ignition
# 4  engine_ignition

# %% [markdown]
# Так как XGBoostClassifier (dart) не поддержал метку качетсва - accuracy, то в данном случае считаю целесообразным в дальнейшем не брать данный механизм.

# %% [markdown]
# **Hard Voting** — метод, при котором делаем голосование всех моделей и выбираем самый популярный класс

# %%
import pandas as pd

# %%
cat_model  = pd.read_csv("/content/catboost_info/catboost_preds.csv")["target"]      # 0.9430199430199431 - лучщий результат
lgbm_model = pd.read_csv("/content/catboost_info/lgbm_preds.csv")["target"]     # 0.9358974358974359 - худщий
rf_model = pd.read_csv("/content/catboost_info/rf_model.csv")["target"]       # 0.9387464387464387 - средний

# %%
import numpy as np

# %%
from scipy.stats import mode

predictions = np.vstack((cat_model, lgbm_model, rf_model))
predictions
# Out:
# array([['engine_fuel', 'electro_bug', 'engine_overheat', ...,
#         'engine_check', 'another_bug', 'engine_ignition'],
#        ['engine_overheat', 'electro_bug', 'engine_overheat', ...,
#         'engine_check', 'another_bug', 'engine_ignition'],
#        ['engine_fuel', 'electro_bug', 'engine_overheat', ...,
#         'engine_check', 'another_bug', 'engine_ignition']], dtype=object)

# %%
# !pip install scipy==1.9.0 #иначе код не работает
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 MB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 53.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# ...

# %%
hard_voting_predictions, _ = mode(mode(predictions, axis=0))
# Out:
# <ipython-input-7-fb06bf79cd3a>:1: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   hard_voting_predictions, _ = mode(mode(predictions, axis=0))
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py:110: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   warnings.warn("The input array could not be properly "
# ...

# %%
hard_voting_predictions
# Out:
# array([[['engine_fuel', 'electro_bug', 'engine_overheat',
#          'engine_ignition', 'engine_ignition', 'electro_bug',
#          'wheel_shake', 'electro_bug', 'engine_check', 'electro_bug',
#          'electro_bug', 'gear_stick', 'another_bug', 'break_bug',
#          'electro_bug', 'engine_overheat', 'engine_fuel',
#          'engine_overheat', 'another_bug', 'electro_bug', 'electro_bug',
#          'engine_fuel', 'engine_ignition', 'engine_check',
#          'electro_bug', 'gear_stick', 'break_bug', 'engine_check',
#          'wheel_shake', 'engine_fuel', 'electro_bug', 'wheel_shake',
#          'another_bug', 'another_bug', 'wheel_shake', 'engine_fuel',
#          'electro_bug', 'engine_ignition', 'electro_bug', 'wheel_shake',
#          'another_bug', 'engine_check', 'another_bug',
#          'engine_overheat', 'engine_ignition', 'break_bug',
#          'engine_overheat', 'engine_ignition', 'break_bug',
#          'engine_ignition', 'wheel_shake', 'engine_fuel',
# ...

# %%
hard_voting_predictions.shape
# Out:
# (1, 1, 702)

# %%
hard_voting_predictions = hard_voting_predictions.reshape(-1)

print(hard_voting_predictions.shape)  # Выводит (702,)
# Out:
# (702,)

# %%
y_test.shape
# Out:
# (702,)

# %%
from sklearn import metrics

# %%
metrics.accuracy_score(y_test, hard_voting_predictions)
# Out:
# 0.9401709401709402

# %% [markdown]
# Используя Hard Voting - прироста точности не произошло...

# %% [markdown]
# ---

# %% [markdown]
# **Soft Voting** — метод, при котором мы складываем вероятности предсказания всех моделей по каждому классу и потом выбираем самый класс с максимальной суммой

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   model                   2337 non-null   category
#  1   car_type                2337 non-null   category
#  2   fuel_type               2337 non-null   category
#  3   car_rating              2337 non-null   float64
#  4   year_to_start           2337 non-null   int64
#  5   riders                  2337 non-null   int64
#  6   year_to_work            2337 non-null   int64
#  7   min_rating              2337 non-null   float64
#  8   mean_rating             2337 non-null   float64
#  9   sum_distance            2337 non-null   float64
#  10  max_speed               2337 non-null   float64
#  11  total_stops             2337 non-null   int64
#  12  sum_ride_duration       2337 non-null   int64
#  13  min_deviation_normal    2337 non-null   float64
# ...

# %%
### Заменим категориальные признаки на числовые значения
cat_cols = ["model", "car_type", "fuel_type"]
for col in cat_cols:
    X[col] = X[col].replace(np.unique(X[col]), np.arange(X[col].nunique())).astype(int)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2337 entries, 0 to 2336
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   model                   2337 non-null   int64
#  1   car_type                2337 non-null   int64
#  2   fuel_type               2337 non-null   int64
#  3   car_rating              2337 non-null   float64
#  4   year_to_start           2337 non-null   int64
#  5   riders                  2337 non-null   int64
#  6   year_to_work            2337 non-null   int64
#  7   min_rating              2337 non-null   float64
#  8   mean_rating             2337 non-null   float64
#  9   sum_distance            2337 non-null   float64
#  10  max_speed               2337 non-null   float64
#  11  total_stops             2337 non-null   int64
#  12  sum_ride_duration       2337 non-null   int64
#  13  min_deviation_normal    2337 non-null   float64
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Создаем новый голосующий классификатор с обновленными данными
models = [('cat_model', cat_model), ('lgbm_model', lgbm_model), ('rf_model', rf_model)]
voting = VotingClassifier(estimators=models, voting='soft')

# Обучаем голосующий классификатор на обновленных данных
voting.fit(X_train, y_train)

# Делаем предсказания на тестовых данных
y_preds = voting.predict_proba(X_test)[:, 1]
# Out:
# Learning rate set to 0.081136
# 0:	learn: 1.8674530	total: 71.4ms	remaining: 1m 11s
# 1:	learn: 1.6427332	total: 124ms	remaining: 1m 1s
# 2:	learn: 1.4484489	total: 164ms	remaining: 54.5s
# 3:	learn: 1.2967482	total: 207ms	remaining: 51.5s
# 4:	learn: 1.1920391	total: 265ms	remaining: 52.7s
# 5:	learn: 1.1033554	total: 302ms	remaining: 50.1s
# 6:	learn: 1.0049626	total: 349ms	remaining: 49.5s
# 7:	learn: 0.9179190	total: 395ms	remaining: 49s
# 8:	learn: 0.8456195	total: 431ms	remaining: 47.5s
# 9:	learn: 0.7877076	total: 484ms	remaining: 47.9s
# 10:	learn: 0.7383563	total: 516ms	remaining: 46.4s
# 11:	learn: 0.6937943	total: 547ms	remaining: 45s
# 12:	learn: 0.6533418	total: 587ms	remaining: 44.6s
# 13:	learn: 0.6143361	total: 631ms	remaining: 44.4s
# 14:	learn: 0.5766240	total: 678ms	remaining: 44.5s
# 15:	learn: 0.5481407	total: 729ms	remaining: 44.8s
# 16:	learn: 0.5167281	total: 781ms	remaining: 45.2s
# 17:	learn: 0.4893563	total: 842ms	remaining: 46s
# ...

# %%
y_test.shape
# Out:
# (702,)

# %%
y_test.shape
# Out:
# (702,)

# %%
from sklearn.metrics import accuracy_score

# Вычисляем точность (accuracy) для многоклассовой классификации
accuracy = accuracy_score(y_test, y_test)
print("Accuracy Score:", accuracy)
# Out:
# Accuracy Score: 1.0

# %%
import joblib

# Сохраняем модель
joblib.dump(voting, 'voting_model.pkl')

# Загружаем модель из файла
loaded_model = joblib.load('voting_model.pkl')

# Делаем предсказания с загруженной моделью
y_preds_loaded = loaded_model.predict_proba(X_test)[:, 1]

# %% [markdown]
# ### Общая информация о блендинге

# %% [markdown]
# **Основная идея** — взять от каждого алгоритма лучшее и совместить несколько разных ML-моделей в одну.
#
# Что это дает:
# - Увеличивается обобщающая способность финальной модели и качество улучшается.
# - Модель становится более стабильной, что позволяет не слететь на приватном лидерборде.
#
# Особенно хорошо накидывает блендинг, если смешиваемые модели имеют разную природу — например, нейронные сети, kNN и решающие деревья. Они выучивают разные зависимости и хорошо дополняют друг друга.
#
# </div>

# %% [markdown]
# # <center id="part6"> Отправка финального решения на лидерборд на Kaggle

# %% [markdown]
# <div class="alert alert-info">
#
# **Цель блока** — сделать предсказание с помощью блендинга для тестовой части датасета, отправить результат [в соревнование на Kaggle](https://www.kaggle.com/competitions/competative-data-science-course-by-data-feeling/overview).

# %% [markdown]
# ## Задание 8. Предсказание на тестовом датасете и отправка на Kaggle

# %% [markdown]
# 1. Сделать предобработку для тестового датасета, присоединить к нему информацию из других датасетов и добавить признаки, которые генерировали для тренировочного датасета.
# 2. Сделать предсказания каждой моделью, которую хотите включить в ансамбль, но минимум их должно быть 3.
# 3. Сделать блендинг с помощью `Hard Voting` или `Soft Voting` на ваш выбор.
# 4. Сохранить результат предсказания в `csv` файл и отправить решение на Kaggle.
#
# <h4> Критерии оценивания </h4>
#
# - 0 баллов за задание, если итоговый скор на лидерборде меньше чем `0.9`.
# - 1 балл за каждый выполненный пункт.
#
# </div>

# %%
car_test = pd.read_csv('https://raw.githubusercontent.com/a-milenkin/Competitive_Data_Science/main/data/car_test.csv')
car_test.head(3)
# Out:
#        car_id            model  car_type fuel_type  car_rating  year_to_start  \
# 0  P17494612l      Skoda Rapid   economy    petrol        4.80           2013
# 1  N-1530212S  Renault Sandero  standart    petrol        4.32           2015
# 2  B-1154399t     Smart ForTwo   economy    petrol        4.46           2015
#
#    riders  year_to_work
# 0   42269          2019
# 1   90014          2016
# 2   82684          2017

# %% [markdown]
# ### Советы по отправке кода на Kaggle

# %% [markdown]
# Если пишете код на `Kaggle`, то для отправки решения:
#
# 1. Нажать Save Version.
# 2. Проверить, что в Advanced Settings выбрано «Всегда сохранять результаты ноутбука».
# 3. Выбрать тип сохранения Save & Run All (Commit).
# 4. Нажать кнопку Save.
